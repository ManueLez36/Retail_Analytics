# %%
# ==========================================
# 1. Cargar y poblar Dimensión Clientes en Gold
# ==========================================
df_clientes_silver = spark.table("retail.02_silver.clientes")

dim_clientes = df_clientes_silver.select(
    "ID_Cliente",
    "Edad",
    "Sexo",
    "EstCivil",
    "Segmento_RFM"
).dropDuplicates(["ID_Cliente"])

dim_clientes.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("retail.03_gold.dim_clientes")

print("¡Dimensión clientes cargada con éxito en Gold!")
# Out:
# ¡Dimensión clientes cargada con éxito en Gold!

# %%
# %sql
select * from retail.03_gold.dim_clientes
limit(5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_Cliente</th><th>Edad</th><th>Sexo</th><th>EstCivil</th><th>Segmento_RFM</th></tr></thead><tbody><tr><td>63529974</td><td>53</td><td>Masculino</td><td>CASADO</td><td>Ocasional</td></tr><tr><td>49173228</td><td>68</td><td>Masculino</td><td>CASADO</td><td>Ocasional</td></tr><tr><td>70795246</td><td>50</td><td>Femenino</td><td>SOLTERO</td><td>Ocasional</td></tr><tr><td>58592656</td><td>51</td><td>Femenino</td><td>CASADO</td><td>Habitual</td></tr><tr><td>69437503</td><td>45</td><td>Masculino</td><td>CASADO</td><td>Ocasional</td></tr></tbody></table></div>

# %%
# ==========================================
# 2. Cargar y poblar Hechos de Ventas en Gold
# ==========================================
df_ventas_silver = spark.table("retail.02_silver.ventas")

fact_ventas = df_ventas_silver.select(
    "CodTicket",
    "ID_Cliente",
    "CodMaterial",
    "SKU",
    "Producto",
    "Descripción", # Con su tilde correcta
    "Tipo",
    "VTABS",
    "Margen",
    "VTAQ",
    "IGV"
)

fact_ventas.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("retail.03_gold.fact_ventas")

print("¡Tabla de hechos de ventas cargada con éxito en Gold!")
# Out:
# ¡Tabla de hechos de ventas cargada con éxito en Gold!

# %%
# %sql
select * from retail.03_gold.fact_ventas
limit(5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
