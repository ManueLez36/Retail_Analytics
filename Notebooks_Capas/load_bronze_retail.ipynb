# %%
# 1. Leemos el archivo nuevamente cliente_df
clientes_df = spark.read.csv("/Volumes/retail/dataset/landing/Clientes.csv", sep =';', header=True, inferSchema=True)

# 2. Guardamos los datos en la tabla Delta
clientes_df.write.mode("append").saveAsTable("retail.01_bronze.clientes_df")

# %%
# 1. Leemos el archivo nuevamente ventas_df
ventas_df = spark.read.csv("/Volumes/retail/dataset/landing/Data_Ventas.csv", sep =';', header=True, inferSchema=True)

ventas_df.write.mode("append").saveAsTable("retail.01_bronze.ventas_df")
